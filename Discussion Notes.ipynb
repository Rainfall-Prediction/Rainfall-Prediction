# %% [markdown]
# # Discussion Notes

# %% [markdown]
# ### Meeting 1 : 28 May 2021

# %% [markdown]
# #### 1.1 : See if Risk_MM and Rainfall features are actually same or not
# Our observation on the data : The RISK_MM feature as we know tells us about the amount of rainfall on the next day. Basically, the rainfall recorded for the day is taken as the risk for the following day. And this pattern can also be seen in the data as we scroll through and apply filters to our data.
#
# Infact, there are only 21 rows that do not follow this trend.

# %% [markdown]
# ![capture.jpg](attachment:capture.jpg)

# %% [markdown]
# #### 1.2 : Sir suggested to think of it as both a classification as well as a regression problem, where we first predict whether it will rain tomorrow or not, and if yes then we predict how much rain(in mm) will happen.
# We discussed about this and agreed to Sir’s suggestion. We plan to  work accordingly in the coming weeks.

# %% [markdown]
# #### 1.3 : Sir suggested to dig deeper and understand the data and its features better taking the help of references in the domain of the project. Also look at the distributions and histograms to know the distributions.
# We worked upon it this fortnight and got to know some really interesting facts and trends in our data.

# %% [markdown]
# #### 1.4 : Based on the trends we observe in the data, think of the ways of handling missing values in the data. See each slice of the data where
# We have worked upon this and come up with a solution. According to our observations, we’ve decided to replace the missing values in the columns : “MinTemp”, “MaxTemp”, “Rainfall”, “WindSpeed9am”, “WindSpeed3pm”, “Humidity9am”, “Humidity3pm”, “Temp9am”, “Temp3pm” using the following method : Replacing the missing observation in the data by the mean of corresponding location and month taken together.
#
# Now for the columns : “Evaporation”, “Sunshine”, “WindGustSpeed”, “WindGustDir”, “WindDir9am”, “WindDir3pm”, “Pressure9am”, “Pressure3pm”, “Cloud9am”, “Cloud3pm” – We use MICE Imputation technique because for these columns, the data for some locations as a whole was missing.
#
# Multiple Imputation by Chained Equations (MICE) is a robust, informative method of dealing with missing data in datasets. The procedure ‘fills in’ (imputes) missing data in a dataset through an iterative series of predictive models. In each iteration, each specified variable in the dataset is imputed using the other variables in the dataset.  MICE imputes missing values in the variables of a data set by using a divide and conquer approach - in other words, by focusing on one variable at a time. Once the focus is placed on one variable, MICE uses all the other variables in the data set (or a sensibly chosen subset of these variables) to predict missingness in that variable. The prediction is based on a regression model, with the form of the model depending on the nature of the focus variable
